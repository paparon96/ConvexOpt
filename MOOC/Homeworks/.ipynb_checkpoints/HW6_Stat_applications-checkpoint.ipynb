# %% [markdown]
# # Import packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cvxpy as cvx

# %% [markdown]
# # Exercise 1

# %%
# # Parameters
# N = 100
# k = 3
# h = np.array([0.3,0.3,0.4])
# x_true = [np.random.uniform(0,0.2) for i in range(0,N)]
# x_true2 = [0]
# for i in range(1,N):
#   x_true2.append(x_true[i]+x_true2[-1])

# x_true = np.array(x_true2)
# y_true = cp.conv(h,x_true)
# y_measurement = y_true[:-2] + np.random.normal(0,1,(N,1))

# %%
# y_measurement

# %%
# plt.plot(x_true2)

# %%
# print(cp.conv(h,h))

# %%
# Source of solution
#https://github.com/NoamGit/CVX101-HW-with-python/blob/master/HW6/HW6.ipynb

# %%
# create problem data 
N = 100; 

# create an increasing input signal
xtrue = np.zeros((N,1))
xtrue[1:40] = 0.1
xtrue[50] = 2
xtrue[70:80] = 0.15;
xtrue[80] = 1
xtrue = np.cumsum(xtrue)

# pass the increasing input through a moving-average filter 
# and add Gaussian noise
h = np.array([1, -0.85 ,0.7 ,-0.3])
k = h.shape[0]
yhat = np.convolve(h,xtrue)
y = yhat[:-3]\
    + np.array([-0.43,-1.7,0.13,0.29,-1.1,1.2,1.2,-0.038,0.33,0.17,-0.19,0.73,-0.59,2.2,-0.14,0.11,1.1,0.059,-0.096,-0.83,0.29,-1.3,0.71,1.6,-0.69,0.86,1.3,-1.6,-1.4,0.57,-0.4,0.69,0.82,0.71,1.3,0.67,1.2,-1.2,-0.02,-0.16,-1.6,0.26,-1.1,1.4,-0.81,0.53,0.22,-0.92,-2.2,-0.059,-1,0.61,0.51,1.7,0.59,-0.64,0.38,-1,-0.02,-0.048,4.3e-05,-0.32,1.1,-1.9,0.43,0.9,0.73,0.58,0.04,0.68,0.57,-0.26,-0.38,-0.3,-1.5,-0.23,0.12,0.31,1.4,-0.35,0.62,0.8,0.94,-0.99,0.21,0.24,-1,-0.74,1.1,-0.13,0.39,0.088,-0.64,-0.56,0.44,-0.95,0.78,0.57,-0.82,-0.27])

# %%
plt.plot(xtrue)

# %%
plt.plot(y)

# %%
plt.plot(yhat)

# %%
x = cvx.Variable((100,),nonneg = True)
z = y[:,None] - cvx.conv(h,x)[:-3]
constraints = [cvx.diff(x) >= 0]
nll = cvx.Minimize(cvx.sum_squares(z))
prob=cvx.Problem(nll,constraints=constraints)
prob.solve()
# Out:
# 58.61124556531801

# %%
xfree = cvx.Variable((100,))
z = y[:,None] - cvx.conv(h,xfree)[:-3]
constraints = []
nll = cvx.Minimize(cvx.sum_squares(z))
prob=cvx.Problem(nll,constraints=constraints)
prob.solve()
# Out:
# 6.571589066751625e-41

# %%
plt.plot(xtrue,label="True signal")
plt.plot(x.value,label="estimate with constraints")
plt.plot(xfree.value,label="estimate without constraints")
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Exercise 2

# %%
# Parameters and initialisation
mu1 = 8
mu2 = 20
sigma1 = 6
sigma2 = 17.5
rho = -0.25
N = 100
R = np.linspace(-30,69,100)
R1,R2 = np.meshgrid(R,R)
tot_return_mask = R1+R2 <= 0

# %%
# Solve the problem
p1 = np.exp(-(R-mu1)**2/(2*sigma1**2))
p1 /= sum(p1)
p2 = np.exp(-(R-mu2)**2/(2*sigma2**2))
p2 /= sum(p2)
P = cvx.Variable((N,N), nonneg=True)
constraints = [
      P * np.ones((N,1)) == p1[:,None]
    , np.ones((1,N)) * P == p2[None,:]
    , (R-mu1) * P * (R-mu2) == rho*sigma1*sigma2
]
loss = cvx.Maximize(cvx.sum(cvx.multiply(P,tot_return_mask)))
prob = cvx.Problem(loss,constraints)
prob.solve()
# Out:
# /Users/MacBook/opt/anaconda3/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /Users/MacBook/opt/anaconda3/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /Users/MacBook/opt/anaconda3/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /Users/MacBook/opt/anaconda3/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# 0.19723081024811057

# %%
fig = plt.figure(figsize=(13, 7))
ax = plt.axes(projection='3d')
surf = ax.plot_surface(R1, R2, P.value, rstride=1, cstride=1, cmap='coolwarm', edgecolor='none')
ax.set_xlabel('R1')
ax.set_ylabel('R2')
ax.set_zlabel('Density')
ax.set_title('Worst-case distribution')
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.view_init(60, 35)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/projections/__init__.py in get_projection_class(projection)
#      57     try:
# ---> 58         return projection_registry.get_projection_class(projection)
#      59     except KeyError:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/projections/__init__.py in get_projection_class(self, name)
#      24         """
# ---> 25         return self._all_projection_types[name]
#      26
#
# KeyError: '3d'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-daa51c8cfd64> in <module>
#       1 fig = plt.figure(figsize=(13, 7))
# ----> 2 ax = plt.axes(projection='3d')
#       3 surf = ax.plot_surface(R1, R2, P.value, rstride=1, cstride=1, cmap='coolwarm', edgecolor='none')
#       4 ax.set_xlabel('R1')
#       5 ax.set_ylabel('R2')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in axes(arg, **kwargs)
#     875
#     876     if arg is None:
# --> 877         return subplot(111, **kwargs)
#     878     else:
#     879         return gcf().add_axes(arg, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1394         else:
#    1395             projection_class, kwargs, key = \
# -> 1396                 self._process_projection_requirements(*args, **kwargs)
#    1397
#    1398             # try to find the axes with this key in the stack
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in _process_projection_requirements(self, polar, projection, *args, **kwargs)
#    1118
#    1119         if isinstance(projection, str) or projection is None:
# -> 1120             projection_class = projections.get_projection_class(projection)
#    1121         elif hasattr(projection, '_as_mpl_axes'):
#    1122             projection_class, extra_kwargs = projection._as_mpl_axes()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/projections/__init__.py in get_projection_class(projection)
#      58         return projection_registry.get_projection_class(projection)
#      59     except KeyError:
# ---> 60         raise ValueError("Unknown projection %r" % projection)
#      61
#      62
#
# ValueError: Unknown projection '3d'

# %%
fig = plt.figure(figsize=(13, 7))
ax = plt.axes(projection='3d')
w = ax.plot_wireframe(R1, R2, P.value)
ax.set_xlabel('R1')
ax.set_ylabel('R2')
ax.set_zlabel('Density')
ax.set_title('Worst-case distribution');

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.gca()
cfset = ax.contourf(R1, R2, P.value, cmap='coolwarm')
#ax.imshow(np.rot90(P.value), cmap='coolwarm')
cset = ax.contour(R1, R2, P.value, colors='k')
ax.clabel(cset, inline=1, fontsize=10)
ax.set_xlabel('R1')
ax.set_ylabel('R2')
plt.title('Worst-case distribution')
# Out:
# Text(0.5, 1.0, 'Worst-case distribution')
